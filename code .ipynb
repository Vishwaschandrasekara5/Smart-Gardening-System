# %% [markdown]
# ## Task 1: Import Required Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.datasets import load_iris 
from sklearn.preprocessing import StandardScaler 
from sklearn.cluster import KMeans, AgglomerativeClustering 
from scipy.cluster.hierarchy import linkage, dendrogram

# %% [markdown]
# ## Task 2: Feature Scaling and Selection

# %%
# Load Iris dataset 
iris = load_iris() 
X = pd.DataFrame(iris.data, columns=iris.feature_names) 

# Normalize features 
scaler = StandardScaler() 
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Task 3: Apply K-Means Clustering

# %%
kmeans = KMeans(n_clusters=3, random_state=0) 
kmeans.fit(X_scaled) 
labels_kmeans = kmeans.labels_

# %% [markdown]
# ## Task 4: Visualize K-Means Clustering

# %%
plt.figure(figsize=(8,6)) 
plt.scatter(X_scaled[:, 2], X_scaled[:, 3], 
c=labels_kmeans, cmap='viridis', s=60) 
centers = kmeans.cluster_centers_ 
plt.scatter(centers[:, 2], centers[:, 3], c='black', s=200, 
alpha=0.75, marker='X') 
plt.xlabel("Petal Length (normalized)") 
plt.ylabel("Petal Width (normalized)") 
plt.title("K-Means Clustering (Iris)") 
plt.show()

# %% [markdown]
# ## Task 5: Hierarchical Clustering

# %%
model = AgglomerativeClustering(n_clusters=3, 
linkage='ward') 
labels_hier = model.fit_predict(X_scaled)

# %% [markdown]
# ## Task 6: Dendrogram Visualization

# %%
linkage_matrix = linkage(X_scaled, method='ward') 
plt.figure(figsize=(12, 5)) 
dendrogram(linkage_matrix) 
plt.title("Hierarchical Clustering Dendrogram") 
plt.xlabel("Sample Index") 
plt.ylabel("Distance") 
plt.show()

# %% [markdown]
# ## Task 7: Visualize Hierarchical Clustering Results

# %%
plt.figure(figsize=(8,6)) 
sns.scatterplot(x=X_scaled[:, 2], y=X_scaled[:, 3], 
hue=labels_hier, palette='Set1') 
plt.xlabel("Petal Length (normalized)") 
plt.ylabel("Petal Width (normalized)") 
plt.title("Hierarchical Clustering (Iris)") 
plt.show()
